# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
data = pd.read_csv('dataset-0510/train.csv')

# %%
data.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1  LgwzgklNvy4QCtq5                  8     7   18800            5
# 2  ucIR2NLLsC3T650L                  8     7   19289            4
# 3  jre1pJhcQj91Kdky                  8    21   20385           24
# 4  rQpYpY9nRG7X5mmr                  1    21   20657            2
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              3             2                  6271            2
# 1              1             2                  7885            2
# 2              1             2                  6028            2
# 3              0             2                 18325            0
# 4              4             2                  6880            2
#
#    parking_area  ...  XIV_500  XIV_index_500  XIV_1000  XIV_index_1000  \
# 0           NaN  ...       58              1       157               1
# ...

# %%
data.describe()
# Out:
#        building_material          city        txn_dt   total_floor  \
# count       60000.000000  60000.000000  60000.000000  60000.000000
# mean            7.267917     11.414533  19488.957917      7.638250
# std             2.170741      4.751677    727.331019      5.070314
# min             1.000000      3.000000  18112.000000      1.000000
# 25%             8.000000      7.000000  18892.750000      4.000000
# 50%             8.000000     12.000000  19527.000000      5.000000
# 75%             8.000000     13.000000  20125.000000     12.000000
# max            11.000000     21.000000  20665.000000     29.000000
#
#        building_type  building_use  building_complete_dt   parking_way  \
# count   60000.000000  60000.000000          60000.000000  60000.000000
# mean        1.931817      2.319200          11050.437183      1.585700
# std         1.589972      1.399528           4344.018090      0.778952
# min         0.000000      0.000000            123.000000      0.000000
# ...

# %%
sns.distplot(np.log1p(data['total_price']))

# %%
var1='city'
var2='total_price'

comp = pd.concat([data[var1], data[var2]], axis=1)
comp.plot.scatter(x=var1, y=var2, xlim=(0, 20), ylim=(0, 100000000))

# %%
ignored = ['parking_price', 'parking_area', 'village_income_median']
train = data.drop(columns=ignored)

# %%
corrmat = train.corr()

# %%
k=20
plt.figure(figsize=(16, 16))

cols = corrmat.nlargest(k, 'total_price')['total_price'].index
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f',
                annot_kws={'size': 10}, yticklabels=cols.values, 
                xticklabels=cols.values)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a34970f54ff7> in <module>
# ----> 1 corrmat[corrmat.value>0.7].index
#
# c:\users\bug87\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'
