# %%
# import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score
import numpy as np

# inline 圖 設定視覺化
# %matplotlib inline
sns.set()

# %%
# import test and train資料集
train = pd.read_csv("./dataset-0510/train.csv")
test = pd.read_csv("./dataset-0510/test.csv")

train.head(3)
train.loc[(train['building_type']  == 4) & (train['parking_way'] == 2), 'parking_price']
# Out:
# 4       NaN
# 10      NaN
# 11      NaN
# 15      NaN
# 21      NaN
# 22      NaN
# 28      NaN
# 35      NaN
# 39      NaN
# 41      NaN
# 45      NaN
# 46      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 56      NaN
# 59      NaN
# 66      NaN
# 70      NaN
# 71      NaN
# 72      NaN
# 73      NaN
# 74      NaN
# 77      NaN
# 78      NaN
# 79      NaN
# 87      NaN
# 88      NaN
# 94      NaN
# 96      NaN
#          ..
# 59895   NaN
# 59897   NaN
# 59900   NaN
# 59905   NaN
# 59907   NaN
# 59908   NaN
# 59910   NaN
# 59912   NaN
# 59913   NaN
# 59915   NaN
# 59918   NaN
# 59922   NaN
# 59938   NaN
# 59943   NaN
# 59946   NaN
# 59952   NaN
# 59955   NaN
# 59956   NaN
# 59959   NaN
# 59960   NaN
# 59961   NaN
# 59973   NaN
# 59975   NaN
# 59976   NaN
# 59979   NaN
# 59981   NaN
# 59985   NaN
# 59988   NaN
# 59989   NaN
# 59995   NaN
# Name: parking_price, Length: 15810, dtype: float64

# %%
test.head(3)
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  X5gsdTWGS3W7JJQB                  1    13   18634            2
# 1  BTshNOJyKHnT2YIT                  8     7   20199           10
# 2  dhdymr0lV8N5kZOT                  8    12   19769            4
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              4             2                  1857            2
# 1              3             2                 16011            2
# 2              4            10                 18294            2
#
#    parking_area  ...  XIV_250  XIV_500  XIV_index_500  XIV_1000  \
# 0           NaN  ...        7       21              1       129
# 1           NaN  ...       18       44              1        67
# 2           NaN  ...        0        3              1        35
#
#    XIV_index_1000  XIV_5000  XIV_index_5000  XIV_10000  XIV_index_10000  \
# 0               1      3991               1       8409                1
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 235 entries, building_id to total_price
# dtypes: float64(37), int64(197), object(1)
# memory usage: 107.3+ MB

# %%
train.describe()
# Out:
#        building_material          city        txn_dt   total_floor  \
# count       60000.000000  60000.000000  60000.000000  60000.000000
# mean            7.267917     11.414533  19488.957917      7.638250
# std             2.170741      4.751677    727.331019      5.070314
# min             1.000000      3.000000  18112.000000      1.000000
# 25%             8.000000      7.000000  18892.750000      4.000000
# 50%             8.000000     12.000000  19527.000000      5.000000
# 75%             8.000000     13.000000  20125.000000     12.000000
# max            11.000000     21.000000  20665.000000     29.000000
#
#        building_type  building_use  building_complete_dt   parking_way  \
# count   60000.000000  60000.000000          60000.000000  60000.000000
# mean        1.931817      2.319200          11050.437183      1.585700
# std         1.589972      1.399528           4344.018090      0.778952
# min         0.000000      0.000000            123.000000      0.000000
# ...

# %%
sns.countplot(x="city", data=train)

# %%
sns.distplot(train.total_price, kde=False)

# %%
train["new_price"] = np.log(train["total_price"])
train.info()
train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 236 entries, building_id to new_price
# dtypes: float64(38), int64(197), object(1)
# memory usage: 107.8+ MB
#        building_material          city        txn_dt   total_floor  \
# count       60000.000000  60000.000000  60000.000000  60000.000000
# mean            7.267917     11.414533  19488.957917      7.638250
# std             2.170741      4.751677    727.331019      5.070314
# min             1.000000      3.000000  18112.000000      1.000000
# 25%             8.000000      7.000000  18892.750000      4.000000
# 50%             8.000000     12.000000  19527.000000      5.000000
# 75%             8.000000     13.000000  20125.000000     12.000000
# max            11.000000     21.000000  20665.000000     29.000000
#
#        building_type  building_use  building_complete_dt   parking_way  \
# count   60000.000000  60000.000000          60000.000000  60000.000000
# ...

# %%
sns.distplot(train.new_price, kde=False)

# %%
train.groupby("city").new_price.hist(alpha=0.6)
# Out:
# city
# 3     AxesSubplot(0.125,0.125;0.775x0.755)
# 5     AxesSubplot(0.125,0.125;0.775x0.755)
# 6     AxesSubplot(0.125,0.125;0.775x0.755)
# 7     AxesSubplot(0.125,0.125;0.775x0.755)
# 9     AxesSubplot(0.125,0.125;0.775x0.755)
# 10    AxesSubplot(0.125,0.125;0.775x0.755)
# 12    AxesSubplot(0.125,0.125;0.775x0.755)
# 13    AxesSubplot(0.125,0.125;0.775x0.755)
# 14    AxesSubplot(0.125,0.125;0.775x0.755)
# 17    AxesSubplot(0.125,0.125;0.775x0.755)
# 21    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: new_price, dtype: object
